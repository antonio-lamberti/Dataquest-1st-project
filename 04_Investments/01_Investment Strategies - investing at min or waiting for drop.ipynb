        ["Zions Bancorporation N.A.","ZION",0.023517],["NRG Energy Inc.","NRG",0.023479],["Federal Realty Investment Trust","FRT",0.023081],["Organon & Co.","OGN",0.022834],["News Corporation Class A","NWSA",0.022747],["Signature Bank","SBNY",0.022084],["DENTSPLY SIRONA Inc.","XRAY",0.021835],["Assurant Inc.","AIZ",0.020374],["Generac Holdings Inc.","GNRC",0.020031],["DXC Technology Co.","DXC",0.019866],["Mohawk Industries Inc.","MHK",0.01762],["Norwegian Cruise Line Holdings Ltd.","NCLH",0.017473],["Alaska Air Group Inc.","ALK",0.017329],["Newell Brands Inc","NWL",0.01676],["Lumen Technologies Inc.","LUMN",0.015085],["Ralph Lauren Corporation Class A","RL",0.015011],["Lincoln National Corp","LNC",0.01452],["DaVita Inc.","DVA",0.013406],["Fox Corporation Class B","FOX",0.01319],["DISH Network Corporation Class A","DISH",0.011947],["News Corporation Class B","NWS",0.007208]]
tickers=list(np.array(SeP500)[:,1])
nomi=list(np.array(SeP500)[:,0])

# %%
dati=yf.download(tickers)["Adj Close"]
# Out:
# [*********************100%***********************]  503 of 503 completed

# %%
# rimetto a posto le colonne che non ho capito perché me le scombina
dati=dati.reindex(tickers, axis=1)

# %%
dati["AAPL"].loc["2006":].plot(figsize=(25,15))
dati["AAPL"].loc["2006":].dropna().cummax().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dati["JNJ"].loc["2013":].plot(figsize=(25,15))
dati["JNJ"].loc["2013":].dropna().cummax().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
datimax=dati.cummax()
drawdown=(dati-datimax)/datimax
cummin=drawdown.cummin()
logret=np.log(dati/dati.shift(1))

# %% [markdown]
# ### Impedisco di investire nel primo anno

# %%
cummin2=cummin.copy()
logret2=logret.copy()

# %%
times2=logret2.apply(pd.Series.first_valid_index)+ pd.offsets.DateOffset(years=1)
for t in tickers:
    logret2[t].loc[:times2[t]]=np.nan
    cummin2[t].loc[:times2[t]]=np.nan

# %%
times=(logret2.index[-1]-times2)/np.timedelta64(1, 'Y')

# %% [markdown]
# ## Soglia 0.3

# %%
soglia=0.3
# strategia 1: buy and hold
# strategia 2: compro quando scende sotto il drawdown e tengo fino alla fine
# strategia 3: compro quando scende sotto il drawdown e tengo fino alla risalita

# %%
strategia1=100*(np.exp(logret2.sum()/times)-1)
strategia1
# Out:
# AAPL     20.876250
# MSFT     22.824050
# AMZN     26.063171
# BRK-B    10.297233
# GOOGL    16.248101
#            ...
# LNC       5.901550
# DVA       9.586076
# FOX      11.841338
# DISH      6.783176
# NWS       2.464485
# Length: 503, dtype: float64

# %%
strategia2=100*(np.exp(((cummin2<-soglia)*logret2).sum()/times)-1)
strategia2
# Out:
# AAPL     20.876250
# MSFT     21.302561
# AMZN     26.063171
# BRK-B     8.725525
# GOOGL    11.682944
#            ...
# LNC       4.805727
# DVA      10.284578
# FOX      11.841338
# DISH      7.264221
# NWS       5.805999
# Length: 503, dtype: float64

# %%
t1=logret.apply(pd.Series.first_valid_index)
t2=(cummin2<-soglia).eq(True).idxmax()
d1=dati.iloc[0].copy()
d2=dati.iloc[0].copy()
mm=dati.iloc[0].copy()
tm=t2.copy()
for t in tickers:
    d1[t]=dati[t].loc[t1[t]]
    d2[t]=dati[t].loc[t2[t]]
# NEE          1973-02-22   0.389877   1973-03-13   0.423030      1974-02-25
# CMCSA        1980-03-18   0.068238   1981-05-21   0.187654      1981-09-25
# WFC          1972-06-02   0.148935   1973-10-30   0.245917      1974-05-10
# TXN          1972-06-02   0.770303   1973-10-12   1.286320      1973-12-13
# ADBE         1986-08-14   0.209060   1987-05-05   1.584453      1987-08-17
# LIN          1992-06-18   4.637535   1997-07-21  18.193213      1998-08-27
# PM           2008-03-18  24.800337   2008-08-12  28.226189      2009-03-19
# NKE          1980-12-03   0.127474   1982-12-08   0.313727      1983-01-11
# BMY          1972-06-02   0.332630   1972-08-10   0.381656      1973-12-11
# CRM          2004-06-24   4.190000   2004-11-02   5.490000      2005-06-27
# RTX          1962-04-03   0.094913   1966-04-20   0.341528      1966-10-06
# COP          1982-01-04   1.071323   1982-01-18   1.078038      1983-01-05
# AMGN         1983-06-20   0.224463   1983-06-22   0.232204      1984-06-21
# HON          1962-01-03   1.116203   1962-01-08   1.126146      1963-01-04
#
#          prezzo2
# AAPL    0.067638
# MSFT    0.196051
# AMZN    0.366927
# BRK-B  37.400002
# GOOGL  12.910410
# GOOG   12.849338
# JNJ     0.053508
# UNH     0.258204
# XOM     0.141469
# JPM     1.364652
# NVDA    0.776743
# PG      0.217238
# V      12.578486
# HD      0.282627
# TSLA    1.934667
# MA     20.095049
# CVX     0.445683
# META   25.160000
# ABBV   35.212490
# MRK     0.064415
# LLY     0.908994
# PFE     0.154993
# PEP     0.304939
# KO      0.250945
# BAC     1.294933
# AVGO   20.190964
# TMO     1.916347
# COST    8.425297
# WMT     0.023378
# CSCO    0.139433
# MCD     0.208804
# ABT     1.180671
# VZ     15.126930
# DIS     0.050705
# ACN    10.822816
# DHR     0.095325
# NEE     0.262571
# CMCSA   0.131358
# WFC     0.170917
# TXN     0.887118
# ADBE    1.085644
# LIN    12.206602
# PM     19.205423
# NKE     0.219538
# BMY     0.261395
# CRM     5.060000
# RTX     0.223258
# COP     1.001867
# AMGN    0.087077
# HON     0.907728

# %%
sottoSoglia=(cummin2<-soglia)
s3=(cummin2<-soglia) & (drawdown<0)
j=0
for t in tickers:
    print(t,j)
    j+=1
    for i in dati.index:
        if sottoSoglia[t].loc[i] and not (s3[t].loc[i]):
            cummin2[t].loc[i:]=(drawdown[t].loc[i:]).cummin()
            sottoSoglia[t]=(cummin2[t]<-soglia)
            s3[t]=((cummin2[t]<-soglia) & (drawdown[t]<0))
# Out:
# AAPL 0
# MSFT 1
# AMZN 2
# BRK-B 3
# GOOGL 4
# GOOG 5
# JNJ 6
# UNH 7
# XOM 8
# JPM 9
# NVDA 10
# PG 11
# V 12
# HD 13
# TSLA 14
# MA 15
# CVX 16
# META 17
# ABBV 18
# MRK 19
# LLY 20
# PFE 21
# PEP 22
# KO 23
# BAC 24
# AVGO 25
# TMO 26
# COST 27
# WMT 28
# CSCO 29
# MCD 30
# ABT 31
# VZ 32
# DIS 33
# ACN 34
# DHR 35
# BXP 463
# CZR 464
# AAP 465
# CCL 466
# BIO 467
# HII 468
# CMA 469
# IVZ 470
# CTLT 471
# FFIV 472
# PNW 473
# ROL 474
# RHI 475
# WHR 476
# HAS 477
# AOS 478
# SEE 479
# PNR 480
# BEN 481
# ZION 482
# NRG 483
# FRT 484
# OGN 485
# NWSA 486
# SBNY 487
# XRAY 488
# AIZ 489
# GNRC 490
# DXC 491
# MHK 492
# NCLH 493
# ALK 494
# NWL 495
# LUMN 496
# RL 497
# LNC 498
# DVA 499
# FOX 500
# DISH 501
# NWS 502

# %%
strategia3=100*(np.exp((s3*logret2).sum()/times)-1)
strategia3
# Out:
# AAPL      9.505186
# MSFT      2.878837
# AMZN      5.304996
# BRK-B     2.938094
# GOOGL     2.823193
#            ...
# LNC       2.183801
# DVA       6.606984
# FOX      22.403406
# DISH     -1.814198
# NWS       7.579232
# Length: 503, dtype: float64

# %%
print("buy&hold:",round(strategia1.mean(),1),"%  -  strategia 2:",round(strategia2.mean(),1),"%  -  strategia 3:",round(strategia3.mean(),1),"%")
# Out:
# buy&hold: 13.9 %  -  strategia 2: 12.8 %  -  strategia 3: 5.6 %

# %%
limite=50
print("buy&hold:",round(strategia1[limite:].mean(),1),"%  -  strategia 2:",round(strategia2[limite:].mean(),1),"%  -  strategia 3:",round(strategia3[limite:].mean(),1),"%")
# Out:
# buy&hold: 13.6 %  -  strategia 2: 12.4 %  -  strategia 3: 5.7 %

# %%
plt.xticks(range(-10,50,5))
plt.xlabel("Rendimento annualizzato %",fontdict = {'fontsize' : 24})
strategia1.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="buy&hold",fontsize=20,color="green")
strategia2.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="strategia 2",fontsize=20,color="red",alpha=0.8)
strategia3.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="strategia 3",fontsize=20,color="blue",alpha=0.6)
plt.legend(fontsize=30)
plt.ylabel("Frequenza",fontdict = {'fontsize' : 24})
# Out:
# Text(0, 0.5, 'Frequenza')

# %% [markdown]
# # soglia 0.1

# %%
cummin2=cummin.copy()
logret2=logret.copy()

# %%
times2=logret2.apply(pd.Series.first_valid_index)+ pd.offsets.DateOffset(years=1)
for t in tickers:
    logret2[t].loc[:times2[t]]=np.nan
    cummin2[t].loc[:times2[t]]=np.nan

# %%
times=(logret2.index[-1]-times2)/np.timedelta64(1, 'Y')

# %%
soglia=0.1
# strategia 1: buy and hold
# strategia 2: compro quando scende sotto il drawdown e tengo fino alla fine
# strategia 3: compro quando scende sotto il drawdown e tengo fino alla risalita

# %%
strategia1=100*(np.exp(logret2.sum()/times)-1)
strategia1
# Out:
# AAPL     20.876250
# MSFT     22.824050
# AMZN     26.063171
# BRK-B    10.297233
# GOOGL    16.248101
#            ...
# LNC       5.901550
# DVA       9.586076
# FOX      11.841338
# DISH      6.783176
# NWS       2.464485
# Length: 503, dtype: float64

# %%
strategia2=100*(np.exp(((cummin2<-soglia)*logret2).sum()/times)-1)
strategia2
# Out:
# AAPL     20.876250
# MSFT     22.824050
# AMZN     26.063171
# BRK-B    10.297233
# GOOGL    16.248101
#            ...
# LNC       5.901550
# DVA       9.586076
# FOX      11.841338
# DISH      6.783176
# NWS       2.464485
# Length: 503, dtype: float64

# %%
t1=logret.apply(pd.Series.first_valid_index)
t2=(cummin2<-soglia).eq(True).idxmax()
d1=dati.iloc[0].copy()
d2=dati.iloc[0].copy()
mm=dati.iloc[0].copy()
tm=t2.copy()
for t in tickers:
    d1[t]=dati[t].loc[t1[t]]
    d2[t]=dati[t].loc[t2[t]]
    temp=dati.index[dati.index.get_loc(t2[t])+1]
    mm[t]=np.max(dati[t].loc[t1[t]:temp])
    try:
        tm[t]=dati[t].loc[t1[t]:temp].idxmax()
    except:
        tm[t]=np.nan
pd.DataFrame({"primo dato valido":t1,"prezzo1":d1,"data massimo":tm,"massimo":mm,"va sotto soglia":t2,"prezzo2":d2})[:50]
# Out:
#       primo dato valido    prezzo1 data massimo    massimo va sotto soglia  \
# AAPL         1980-12-15   0.094519   1980-12-29   0.124869      1981-12-16
# MSFT         1986-03-14   0.062823   1987-03-12   0.186032      1987-03-16
# AMZN         1997-05-16   0.086458   1998-04-16   0.410417      1998-05-18
# BRK-B        1996-05-10  24.000000   1997-05-13  26.620001      1997-05-12
# GOOGL        2004-08-20   2.710460   2005-07-21   7.856356      2005-08-22
# GOOG         2004-08-20   2.697639   2005-07-21   7.819192      2005-08-22
# JNJ          1962-01-03   0.065422   1962-02-07   0.074375      1963-01-04
# UNH          1984-10-18   0.121133   1985-07-22   0.306020      1985-10-21
# XOM          1962-01-03   0.099758   1962-12-26   0.121604      1963-01-04
# JPM          1980-03-18   1.122867   1981-03-19   1.766261      1981-03-19
# NVDA         1999-01-25   0.415857   1999-12-31   0.897438      2000-01-26
# PG           1962-01-03   0.262992   1962-01-03   0.262992      1963-01-04
# V            2008-03-20  14.495992   2008-05-07  19.936213      2009-03-23
# HD           1981-09-23   0.018070   1982-08-26   0.090490      1982-09-24
# TSLA         2010-06-30   1.588667   2010-11-24   2.364667      2011-07-01
# MA           2006-05-26   4.148601   2007-05-30  13.633222      2007-05-29
# CVX          1962-01-03   0.348873   1963-01-07   0.438568      1963-01-04
# META         2012-05-21  34.029999   2012-05-21  34.029999      2013-05-22
# ABBV         2013-01-03  22.915104   2013-12-18  37.165268      2014-01-06
# MRK          1962-01-03   0.067414   1962-03-23   0.074726      1963-01-04
# LLY          1972-06-02   0.924479   1973-03-15   1.279529      1973-06-04
# PFE          1972-06-02   0.172844   1972-08-11   0.194052      1973-06-04
# PEP          1972-06-02   0.416047   1972-12-07   0.437312      1973-06-04
# KO           1962-01-03   0.048557   1962-03-23   0.048997      1963-01-04
# BAC          1973-02-22   1.636574   1973-10-19   1.851479      1974-02-25
# AVGO         2009-08-07  12.105116   2010-06-17  17.203556      2010-08-09
# CBOE 415
# SNA 416
# EQT 417
# POOL 418
# RCL 419
# PKG 420
# GEN 421
# MTCH 422
# MGM 423
# SWK 424
# MKTX 425
# CPT 426
# DPZ 427
# TFX 428
# UDR 429
# BF-B 430
# WDC 431
# CE 432
# CHRW 433
# L 434
# HST 435
# MAS 436
# CRL 437
# CPB 438
# NI 439
# HSIC 440
# PHM 441
# GL 442
# EMN 443
# KMX 444
# STX 445
# TPR 446
# LYV 447
# BBWI 448
# JNPR 449
# BWA 450
# ALLE 451
# UHS 452
# WYNN 453
# PARA 454
# QRVO 455
# CDAY 456
# FOXA 457
# VFC 458
# REG 459
# TAP 460
# AAL 461
# WRK 462
# BXP 463
# CZR 464
# AAP 465
# CCL 466
# BIO 467
# HII 468
# CMA 469
# IVZ 470
# CTLT 471
# FFIV 472
# PNW 473
# ROL 474
# RHI 475
# WHR 476
# HAS 477
# AOS 478
# SEE 479
# PNR 480
# BEN 481
# ZION 482
# NRG 483
# FRT 484
# OGN 485
# NWSA 486
# SBNY 487
# XRAY 488
# AIZ 489
# GNRC 490
# DXC 491
# MHK 492
# NCLH 493
# ALK 494
# NWL 495
# LUMN 496
# RL 497
# LNC 498
# DVA 499
# FOX 500
# DISH 501
# NWS 502

# %%
strategia3=100*(np.exp((s3*logret2).sum()/times)-1)
strategia3
# Out:
# AAPL      6.766912
# MSFT      5.820563
# AMZN      1.738285
# BRK-B     2.685604
# GOOGL     4.160253
#            ...
# LNC       1.700029
# DVA       3.156119
# FOX      12.233512
# DISH     -3.818712
# NWS      -1.116193
# Length: 503, dtype: float64

# %%
print("buy&hold:",round(strategia1.mean(),1),"%  -  strategia 2:",round(strategia2.mean(),1),"%  -  strategia 3:",round(strategia3.mean(),1),"%")
# Out:
# buy&hold: 13.9 %  -  strategia 2: 13.9 %  -  strategia 3: 4.8 %

# %%
limite=50
print("buy&hold:",round(strategia1[limite:].mean(),1),"%  -  strategia 2:",round(strategia2[limite:].mean(),1),"%  -  strategia 3:",round(strategia3[limite:].mean(),1),"%")
# Out:
# buy&hold: 13.6 %  -  strategia 2: 13.6 %  -  strategia 3: 4.7 %

# %%
plt.xticks(range(-10,50,5))
plt.xlabel("Rendimento annualizzato %",fontdict = {'fontsize' : 24})
strategia1.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="buy&hold",fontsize=20,color="green")
strategia2.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="strategia 2",fontsize=20,color="red",alpha=0.8)
strategia3.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="strategia 3",fontsize=20,color="blue",alpha=0.6)
plt.legend(fontsize=30)
plt.ylabel("Frequenza",fontdict = {'fontsize' : 24})
# Out:
# Text(0, 0.5, 'Frequenza')

# %% [markdown]
# # soglia 0.5

# %%
cummin2=cummin.copy()
logret2=logret.copy()

# %%
times2=logret2.apply(pd.Series.first_valid_index)+ pd.offsets.DateOffset(years=1)
for t in tickers:
    logret2[t].loc[:times2[t]]=np.nan
    cummin2[t].loc[:times2[t]]=np.nan

# %%
times=(logret2.index[-1]-times2)/np.timedelta64(1, 'Y')

# %%
soglia=0.5
# strategia 1: buy and hold
# strategia 2: compro quando scende sotto il drawdown e tengo fino alla fine
# strategia 3: compro quando scende sotto il drawdown e tengo fino alla risalita

# %%
strategia1=100*(np.exp(logret2.sum()/times)-1)
strategia1
# Out:
# AAPL     20.876250
# MSFT     22.824050
# AMZN     26.063171
# BRK-B    10.297233
# GOOGL    16.248101
#            ...
# LNC       5.901550
# DVA       9.586076
# FOX      11.841338
# DISH      6.783176
# NWS       2.464485
# Length: 503, dtype: float64

# %%
strategia2=100*(np.exp(((cummin2<-soglia)*logret2).sum()/times)-1)
strategia2
# Out:
# AAPL     20.876250
# MSFT     22.299687
# AMZN     17.061227
# BRK-B     7.292414
# GOOGL    14.389208
#            ...
# LNC       4.805727
# DVA      10.038042
# FOX      17.547802
# DISH      8.354961
# NWS       9.801609
# Length: 503, dtype: float64

# %%
t1=logret.apply(pd.Series.first_valid_index)
t2=(cummin2<-soglia).eq(True).idxmax()
d1=dati.iloc[0].copy()
d2=dati.iloc[0].copy()
mm=dati.iloc[0].copy()
tm=t2.copy()
for t in tickers:
    d1[t]=dati[t].loc[t1[t]]
    d2[t]=dati[t].loc[t2[t]]
    temp=dati.index[dati.index.get_loc(t2[t])+1]
    mm[t]=np.max(dati[t].loc[t1[t]:temp])
    try:
        tm[t]=dati[t].loc[t1[t]:temp].idxmax()
    except:
        tm[t]=np.nan
pd.DataFrame({"primo dato valido":t1,"prezzo1":d1,"data massimo":tm,"massimo":mm,"va sotto soglia":t2,"prezzo2":d2})[:50]
# Out:
#       primo dato valido    prezzo1 data massimo    massimo va sotto soglia  \
# AAPL         1980-12-15   0.094519   1980-12-29   0.124869      1981-12-16
# MSFT         1986-03-14   0.062823   1987-10-05   0.342277      1987-10-26
# AMZN         1997-05-16   0.086458   1999-01-11   4.615625      1999-02-18
# BRK-B        1996-05-10  24.000000   2007-12-10  99.699997      2009-02-20
# GOOGL        2004-08-20   2.710460   2007-11-06  18.563313      2008-10-07
# GOOG         2004-08-20   2.697639   2007-11-06  18.475498      2008-10-07
# JNJ          1962-01-03   0.065422   1972-11-01   0.899508      1977-04-25
# UNH          1984-10-18   0.121133   1986-04-08   0.404839      1986-10-08
# XOM          1962-01-03   0.099758   2014-06-23  70.642700      2020-03-12
# JPM          1980-03-18   1.122867   1986-03-27   4.759783      1987-10-20
# NVDA         1999-01-25   0.415857   2000-03-13   2.853636      2000-04-14
# PG           1962-01-03   0.262992   2000-01-11  31.823322      2000-03-08
# V            2008-03-20  14.495992   2008-05-07  19.936213      2009-03-23
# HD           1981-09-23   0.018070   1983-09-20   0.416502      1984-03-01
# TSLA         2010-06-30   1.588667   2017-09-18  25.666668      2019-05-24
# MA           2006-05-26   4.148601   2008-06-02  29.749420      2008-10-07
# CVX          1962-01-03   0.348873   1973-01-31   0.918014      1974-10-03
# ABT          NaN
# VZ      9.758036
# DIS     0.820664
# ACN    10.822816
# DHR     0.065366
# NEE     0.209526
# CMCSA   0.774257
# WFC     0.120893
# TXN     0.640568
# ADBE    0.777556
# LIN    35.635227
# PM           NaN
# NKE     0.155802
# BMY     0.182255
# CRM     8.985000
# RTX     0.197790
# COP    20.787249
# AMGN    0.087077
# HON     0.641899

# %%
sottoSoglia=(cummin2<-soglia)
s3=(cummin2<-soglia) & (drawdown<0)
j=0
for t in tickers:
    print(t,j)
    j+=1
    for i in dati.index:
        if sottoSoglia[t].loc[i] and not (s3[t].loc[i]):
            cummin2[t].loc[i:]=(drawdown[t].loc[i:]).cummin()
            sottoSoglia[t]=(cummin2[t]<-soglia)
            s3[t]=((cummin2[t]<-soglia) & (drawdown[t]<0))
# Out:
# AAPL 0
# MSFT 1
# AMZN 2
# BRK-B 3
# GOOGL 4
# GOOG 5
# JNJ 6
# UNH 7
# XOM 8
# JPM 9
# NVDA 10
# PG 11
# V 12
# HD 13
# TSLA 14
# MA 15
# CVX 16
# META 17
# ABBV 18
# MRK 19
# LLY 20
# PFE 21
# PEP 22
# KO 23
# BAC 24
# AVGO 25
# TMO 26
# COST 27
# WMT 28
# CSCO 29
# MCD 30
# ABT 31
# VZ 32
# DIS 33
# ACN 34
# DHR 35
# NEE 36
# CMCSA 37
# WFC 38
# TXN 39
# ADBE 40
# LIN 41
# PM 42
# NKE 43
# BMY 44
# CRM 45
# RTX 46
# COP 47
# AMGN 48
# HON 49
# NFLX 50
# T 51
# ORCL 52
# UPS 53
# UNP 54
# SCHW 55
# IBM 56
# CAT 57
# QCOM 58
# LOW 59
# INTC 60
# SBUX 61
# CVS 62
# GS 63
# DE 64
# BA 65
# SPGI 66
# MS 67
# BLK 68
# ELV 69
# INTU 70
# AMD 71
# PLD 72
# LMT 73
# GILD 74
# MDT 75
# AMT 76
# ADP 77
# TJX 78
# ISRG 79
# CB 80
# CI 81
# C 82
# MDLZ 83
# AMAT 84
# AXP 85
# TMUS 86
# PYPL 87
# SYK 88
# ADI 89
# BKNG 90
# MMC 91
# MO 92
# DUK 93
# GE 94
# SLB 95
# SO 96
# PGR 97
# NOW 98
# EOG 99
# VRTX 100
# REGN 101
# TGT 102
# BDX 103
# NOC 104
# MMM 105
# APD 106
# ZTS 107
# CSX 108
# PNC 109
# CL 110
# BSX 111
# FISV 112
# ETN 113
# ITW 114
# AON 115
# CME 116
# EQIX 117
# CCI 118
# USB 119
# LRCX 120
# MU 121
# FCX 122
# HUM 123
# MRNA 124
# TFC 125
# EL 126
# WM 127
# NSC 128
# ICE 129
# KLAC 130
# EMR 131
# SHW 132
# GD 133
# ATVI 134
# PXD 135
# MCK 136
# DG 137
# MPC 138
# HCA 139
# ORLY 140
# D 141
# GM 142
# AEP 143
# GIS 144
# F 145
# VLO 146
# SNPS 147
# SRE 148
# PSX 149
# MET 150
# AIG 151
# EW 152
# APH 153
# ROP 154
# ADM 155
# OXY 156
# AZO 157
# SEDG 371
# AVY 372
# SWKS 373
# ETSY 374
# FDS 375
# GRMN 376
# TXT 377
# WRB 378
# HWM 379
# JBHT 380
# NVR 381
# INCY 382
# TER 383
# SYF 384
# EVRG 385
# IRM 386
# LKQ 387
# SIVB 388
# ZBRA 389
# VTRS 390
# FLT 391
# PAYC 392
# UAL 393
# LW 394
# NTAP 395
# APA 396
# PEAK 397
# EXPE 398
# RE 399
# IPG 400
# AKAM 401
# LNT 402
# ESS 403
# LDOS 404
# BRO 405
# IP 406
# HRL 407
# TYL 408
# PTC 409
# JKHY 410
# TRMB 411
# NDSN 412
# TECH 413
# KIM 414
# CBOE 415
# SNA 416
# EQT 417
# POOL 418
# RCL 419
# PKG 420
# GEN 421
# MTCH 422
# MGM 423
# SWK 424
# MKTX 425
# CPT 426
# DPZ 427
# TFX 428
# UDR 429
# BF-B 430
# WDC 431
# CE 432
# CHRW 433
# L 434
# HST 435
# MAS 436
# CRL 437
# CPB 438
# NI 439
# HSIC 440
# PHM 441
# GL 442
# EMN 443
# KMX 444
# STX 445
# TPR 446
# LYV 447
# BBWI 448
# JNPR 449
# BWA 450
# ALLE 451
# UHS 452
# WYNN 453
# PARA 454
# QRVO 455
# CDAY 456
# FOXA 457
# VFC 458
# REG 459
# TAP 460
# AAL 461
# WRK 462
# BXP 463
# CZR 464
# AAP 465
# CCL 466
# BIO 467
# HII 468
# CMA 469
# IVZ 470
# CTLT 471
# FFIV 472
# PNW 473
# ROL 474
# RHI 475
# WHR 476
# HAS 477
# AOS 478
# SEE 479
# PNR 480
# BEN 481
# ZION 482
# NRG 483
# FRT 484
# OGN 485
# NWSA 486
# SBNY 487
# XRAY 488
# AIZ 489
# GNRC 490
# DXC 491
# MHK 492
# NCLH 493
# ALK 494
# NWL 495
# LUMN 496
# RL 497
# LNC 498
# DVA 499
# FOX 500
# DISH 501
# NWS 502

# %%
strategia3=100*(np.exp((s3*logret2).sum()/times)-1)
strategia3
# Out:
# AAPL      8.672710
# MSFT      3.381718
# AMZN      8.228838
# BRK-B     2.668220
# GOOGL     3.974197
#            ...
# LNC       4.634817
# DVA       2.919857
# FOX      22.107671
# DISH      0.727027
# NWS       7.723417
# Length: 503, dtype: float64

# %%
print("buy&hold:",round(strategia1.mean(),1),"%  -  strategia 2:",round(strategia2.mean(),1),"%  -  strategia 3:",round(strategia3.mean(),1),"%")
# Out:
# buy&hold: 13.9 %  -  strategia 2: 10.6 %  -  strategia 3: 4.7 %

# %%
limite=50
print("buy&hold:",round(strategia1[limite:].mean(),1),"%  -  strategia 2:",round(strategia2[limite:].mean(),1),"%  -  strategia 3:",round(strategia3[limite:].mean(),1),"%")
# Out:
# buy&hold: 13.6 %  -  strategia 2: 10.3 %  -  strategia 3: 4.8 %

# %%
plt.xticks(range(-10,50,5))
plt.xlabel("Rendimento annualizzato %",fontdict = {'fontsize' : 24})
strategia1.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="buy&hold",fontsize=20,color="green")
strategia2.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="strategia 2",fontsize=20,color="red",alpha=0.8)
strategia3.plot(kind="hist",figsize=(25,15),range=[-10,50],bins=100,legend=True,label="strategia 3",fontsize=20,color="blue",alpha=0.6)
plt.legend(fontsize=30)
plt.ylabel("Frequenza",fontdict = {'fontsize' : 24})
# Out:
# Text(0, 0.5, 'Frequenza')

# %% [markdown]
# # Crypto

# %%
# USARE QUESTO PER AVERE S&P500
crypto=[["Bitcoin","BTC-USD",1],["Ethereum","ETH-USD",1]]
tickersc=list(np.array(crypto)[:,1])
nomic=list(np.array(crypto)[:,0])

# %%
datic=yf.download(tickersc)["Adj Close"]
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# rimetto a posto le colonne che non ho capito perché me le scombina
datic=datic.reindex(tickersc, axis=1)

# %%
datic["BTC-USD"].plot(figsize=(25,15))
datic["BTC-USD"].dropna().cummax().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
datic["ETH-USD"].plot(figsize=(25,15))
datic["ETH-USD"].dropna().cummax().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
datimaxc=datic.cummax()
drawdownc=(datic-datimaxc)/datimaxc
cumminc=drawdownc.cummin()
logretc=np.log(datic/datic.shift(1))

# %% [markdown]
# ### Impedisco di investire nel primo anno

# %%
cummin2c=cumminc.copy()
logret2c=logretc.copy()

# %%
times2c=logret2c.apply(pd.Series.first_valid_index)+ pd.offsets.DateOffset(years=1)
for t in tickersc:
    logret2c[t].loc[:times2c[t]]=np.nan
    cummin2c[t].loc[:times2c[t]]=np.nan

# %%
timesc=(logret2c.index[-1]-times2c)/np.timedelta64(1, 'Y')

# %% [markdown]
# # Inizio analisi soglia 0.3

# %%
soglia=0.3
# strategia 1: buy and hold
# strategia 2: compro quando scende sotto il drawdown e tengo fino alla fine
# strategia 3: compro quando scende sotto il drawdown e tengo fino alla risalita

# %%
strategia1=100*(np.exp(logret2c.sum()/timesc)-1)
strategia1
# Out:
# BTC-USD    87.615168
# ETH-USD    62.779200
# dtype: float64

# %%
strategia2=100*(np.exp(((cummin2c<-soglia)*logret2c).sum()/timesc)-1)
strategia2
# Out:
# BTC-USD    87.615168
# ETH-USD    62.779200
# dtype: float64

# %%
t1=logretc.apply(pd.Series.first_valid_index)
t2=(cummin2c<-soglia).eq(True).idxmax()
d1=datic.iloc[0].copy()
d2=datic.iloc[0].copy()
mm=datic.iloc[0].copy()
tm=t2.copy()
for t in tickersc:
    d1[t]=datic[t].loc[t1[t]]
    d2[t]=datic[t].loc[t2[t]]
    temp=datic.index[datic.index.get_loc(t2[t])+1]
    mm[t]=np.max(datic[t].loc[t1[t]:temp])
    try:
        tm[t]=datic[t].loc[t1[t]:temp].idxmax()
    except:
        tm[t]=np.nan
pd.DataFrame({"primo dato valido":t1,"prezzo1":d1,"data massimo":tm,"massimo":mm,"va sotto soglia":t2,"prezzo2":d2})[:50]
# Out:
#         primo dato valido     prezzo1 data massimo      massimo  \
# BTC-USD        2014-09-18  424.440002   2014-09-23   435.790985
# ETH-USD        2017-11-10  299.252991   2018-01-13  1396.420044
#
#         va sotto soglia     prezzo2
# BTC-USD      2015-09-19  231.492996
# ETH-USD      2018-11-11  211.339996

# %%
sottoSogliac=(cummin2c<-soglia)
s3c=(cummin2c<-soglia) & (drawdownc<0)
j=0
for t in tickersc:
    print(t,j)
    j+=1
    for i in datic.index:
        if sottoSogliac[t].loc[i] and not (s3c[t].loc[i]):
            cummin2c[t].loc[i:]=(drawdownc[t].loc[i:]).cummin()
            sottoSogliac[t]=(cummin2c[t]<-soglia)
            s3c[t]=((cummin2c[t]<-soglia) & (drawdownc[t]<0))
# Out:
# BTC-USD 0
# ETH-USD 1

# %%
strategia3=100*(np.exp((s3c*logret2c).sum()/timesc)-1)
strategia3
# Out:
# BTC-USD    17.236391
# ETH-USD    36.416482
# dtype: float64

# %% [markdown]
# ## Soglia 0.5

# %%
cummin2c=cumminc.copy()
logret2c=logretc.copy()

# %%
times2c=logret2c.apply(pd.Series.first_valid_index)+ pd.offsets.DateOffset(years=1)
for t in tickersc:
    logret2c[t].loc[:times2c[t]]=np.nan
    cummin2c[t].loc[:times2c[t]]=np.nan

# %%
timesc=(logret2c.index[-1]-times2c)/np.timedelta64(1, 'Y')

# %%
soglia=0.5
# strategia 1: buy and hold
# strategia 2: compro quando scende sotto il drawdown e tengo fino alla fine
# strategia 3: compro quando scende sotto il drawdown e tengo fino alla risalita

# %%
strategia1=100*(np.exp(logret2c.sum()/timesc)-1)
strategia1
# Out:
# BTC-USD    87.615168
# ETH-USD    62.779200
# dtype: float64

# %%
strategia2=100*(np.exp(((cummin2c<-soglia)*logret2c).sum()/timesc)-1)
strategia2
# Out:
# BTC-USD    87.615168
# ETH-USD    62.779200
# dtype: float64

# %%
t1=logretc.apply(pd.Series.first_valid_index)
t2=(cummin2c<-soglia).eq(True).idxmax()
d1=datic.iloc[0].copy()
d2=datic.iloc[0].copy()
mm=datic.iloc[0].copy()
tm=t2.copy()
for t in tickersc:
    d1[t]=datic[t].loc[t1[t]]
    d2[t]=datic[t].loc[t2[t]]
    temp=datic.index[datic.index.get_loc(t2[t])+1]
    mm[t]=np.max(datic[t].loc[t1[t]:temp])
    try:
        tm[t]=datic[t].loc[t1[t]:temp].idxmax()
    except:
        tm[t]=np.nan
pd.DataFrame({"primo dato valido":t1,"prezzo1":d1,"data massimo":tm,"massimo":mm,"va sotto soglia":t2,"prezzo2":d2})[:50]
# Out:
#         primo dato valido     prezzo1 data massimo      massimo  \
# BTC-USD        2014-09-18  424.440002   2014-09-23   435.790985
# ETH-USD        2017-11-10  299.252991   2018-01-13  1396.420044
#
#         va sotto soglia     prezzo2
# BTC-USD      2015-09-19  231.492996
# ETH-USD      2018-11-11  211.339996

# %%
sottoSogliac=(cummin2c<-soglia)
s3c=(cummin2c<-soglia) & (drawdownc<0)
j=0
for t in tickersc:
    print(t,j)
    j+=1
    for i in datic.index:
        if sottoSogliac[t].loc[i] and not (s3c[t].loc[i]):
            cummin2c[t].loc[i:]=(drawdownc[t].loc[i:]).cummin()
            sottoSogliac[t]=(cummin2c[t]<-soglia)
            s3c[t]=((cummin2c[t]<-soglia) & (drawdownc[t]<0))
# Out:
# BTC-USD 0
# ETH-USD 1

# %%
strategia3=100*(np.exp((s3c*logret2c).sum()/timesc)-1)
strategia3
# Out:
# BTC-USD    21.662221
# ETH-USD    60.672968
# dtype: float64

# %% [markdown]
# ## Soglia 0.1

# %%
cummin2c=cumminc.copy()
logret2c=logretc.copy()

# %%
times2c=logret2c.apply(pd.Series.first_valid_index)+ pd.offsets.DateOffset(years=1)
for t in tickersc:
    logret2c[t].loc[:times2c[t]]=np.nan
    cummin2c[t].loc[:times2c[t]]=np.nan

# %%
timesc=(logret2c.index[-1]-times2c)/np.timedelta64(1, 'Y')

# %%
soglia=0.1
# strategia 1: buy and hold
# strategia 2: compro quando scende sotto il drawdown e tengo fino alla fine
# strategia 3: compro quando scende sotto il drawdown e tengo fino alla risalita

# %%
strategia1=100*(np.exp(logret2c.sum()/timesc)-1)
strategia1
# Out:
# BTC-USD    87.615168
# ETH-USD    62.779200
# dtype: float64

# %%
strategia2=100*(np.exp(((cummin2c<-soglia)*logret2c).sum()/timesc)-1)
strategia2
# Out:
# BTC-USD    87.615168
# ETH-USD    62.779200
# dtype: float64

# %%
t1=logretc.apply(pd.Series.first_valid_index)
t2=(cummin2c<-soglia).eq(True).idxmax()
d1=datic.iloc[0].copy()
d2=datic.iloc[0].copy()
mm=datic.iloc[0].copy()
tm=t2.copy()
for t in tickersc:
    d1[t]=datic[t].loc[t1[t]]
    d2[t]=datic[t].loc[t2[t]]
    temp=datic.index[datic.index.get_loc(t2[t])+1]
    mm[t]=np.max(datic[t].loc[t1[t]:temp])
    try:
        tm[t]=datic[t].loc[t1[t]:temp].idxmax()
    except:
        tm[t]=np.nan
pd.DataFrame({"primo dato valido":t1,"prezzo1":d1,"data massimo":tm,"massimo":mm,"va sotto soglia":t2,"prezzo2":d2})[:50]
# Out:
#         primo dato valido     prezzo1 data massimo      massimo  \
# BTC-USD        2014-09-18  424.440002   2014-09-23   435.790985
# ETH-USD        2017-11-10  299.252991   2018-01-13  1396.420044
#
#         va sotto soglia     prezzo2
# BTC-USD      2015-09-19  231.492996
# ETH-USD      2018-11-11  211.339996

# %%
sottoSogliac=(cummin2c<-soglia)
s3c=(cummin2c<-soglia) & (drawdownc<0)
j=0
for t in tickersc:
    print(t,j)
    j+=1
    for i in datic.index:
        if sottoSogliac[t].loc[i] and not (s3c[t].loc[i]):
            cummin2c[t].loc[i:]=(drawdownc[t].loc[i:]).cummin()
            sottoSogliac[t]=(cummin2c[t]<-soglia)
            s3c[t]=((cummin2c[t]<-soglia) & (drawdownc[t]<0))
# Out:
# BTC-USD 0
# ETH-USD 1

# %%
strategia3=100*(np.exp((s3c*logret2c).sum()/timesc)-1)
strategia3
# Out:
# BTC-USD     2.176777
# ETH-USD    25.983291
# dtype: float64
